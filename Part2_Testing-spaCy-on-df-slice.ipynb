# %%
## Import necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import datetime as dt

# %%
pd.options.display.max_rows = 250
pd.options.display.max_columns = 50

# %%
app_df = pd.read_csv('Data/mha_app_info.csv',
                     usecols=['app_name', 'iOS_app_id', 'android_appID'])
app_df.columns = ['app_name', 'as_id', 'gp_id']
app_df.head()
# Out:
#                          app_name       as_id                       gp_id
# 0                        Aloe Bud  1318382054                         NaN
# 1                            Aura  1114223104              com.aurahealth
# 2                      BetterHelp   995252384              com.betterhelp
# 3                   Breathe2Relax   425720246  org.t2health.breathe2relax
# 4  Breathwrk: Breathing Exercises  1481804500                         NaN

# %%
gp_apps = pd.read_csv('Data/google_play_info.csv')
gp_apps.head()
# Out:
#                         _id                                    title  \
# 0  605a2224fa456042d0948f7e   Aura: Meditations, Sleep & Mindfulness
# 1  605a2224fa456042d0948f7f  BetterHelp: Online Counseling & Therapy
# 2  605a2224fa456042d0948f80                            Breathe2Relax
# 3  605a2224fa456042d0948f81         Breethe - Meditation & Sleep App
# 4  605a2224fa456042d0948f82            Calm - Meditate, Sleep, Relax
#
#                                          description  \
# 0  <b>Find peace everyday with Aura</b> - discove...
# 1  BetterHelp is the convenient way to get profes...
# 2  Breathe2Relax is a portable stress management ...
# 3  Breathe mindfulness, peace and restful sleep i...
# 4  Calm is a leading app for meditation and sleep...
#
#                                      descriptionHTML  \
# 0  <b>Find peace everyday with Aura</b> - discove...
# 1  BetterHelp is the convenient way to get profes...
# 2  Breathe2Relax is a portable stress management ...
# 3  Breathe mindfulness, peace and restful sleep i...
# 4  Calm is a leading app for meditation and sleep...
#
#                                              summary  \
# 0  1000s of Meditations from world's best coaches...
# 1  Get counseling from a licensed therapist, mana...
# 2  Breathe2Relax is a stress management tool to h...
# 3  Sleep, relax, breathe and meditate with medita...
# 4  Join the millions discovering the life-changin...
#
#                                          summaryHTML     installs  \
# 0  1000s of Meditations from world&#39;s best coa...   1,000,000+
# 1  Get counseling from a licensed therapist, mana...   1,000,000+
# 2  Breathe2Relax is a stress management tool to h...     100,000+
# 3  Sleep, relax, breathe and meditate with medita...     500,000+
# 4  Join the millions discovering the life-changin...  10,000,000+
#
#    minInstalls     score  ratings  reviews  \
# 0      1000000  4.593012    10532     3407
# 1      1000000  4.435962    15637     5344
# 2       100000  3.216216     1110      349
# 3       500000  4.590909     3307     1223
# 4     10000000  4.065960   363315   108499
#
#                              histogram  price  free currency   sale  saleTime  \
# 0           [547, 248, 208, 935, 8594]      0  True      USD  False       NaN
# 1        [1489, 286, 276, 1450, 12136]      0  True      USD  False       NaN
# 2             [350, 70, 120, 130, 440]      0  True      USD  False       NaN
# 3            [110, 60, 160, 411, 2566]      0  True      USD  False       NaN
# 4  [61337, 8225, 14811, 39703, 239239]      0  True      USD  False       NaN
#
#    originalPrice  saleText  offersIAP          inAppProductPrice  \
# 0            NaN       NaN       True   $5.99 - $399.99 per item
# 1            NaN       NaN      False                        NaN
# 2            NaN       NaN      False                        NaN
# 3            NaN       NaN       True  $12.99 - $379.99 per item
# 4            NaN       NaN       True   $0.99 - $399.99 per item
#
#                  size androidVersion  androidVersionText  \
# 0                 57M            4.1          4.1 and up
# 1                 39M            6.0          6.0 and up
# 2                3.1M            4.4          4.4 and up
# 3                 76M            7.0          7.0 and up
# 4  Varies with device         Varies  Varies with device
#
#                                        developer  \
# 0  Aura Health - Mindfulness, Sleep, Meditations
# 1                 BetterHelp - Therapy Made Easy
# 2                                             T2
# 3                                        Breethe
# 4                                 Calm.com, Inc.
#
#                                      developerId  \
# 0  Aura+Health+-+Mindfulness,+Sleep,+Meditations
# 1                 BetterHelp+-+Therapy+Made+Easy
# 2                                             T2
# 3                                        Breethe
# 4                                 Calm.com,+Inc.
#
#                                     developerEmail  \
# 0                              hello@aurahealth.io
# 1                           contact@betterhelp.com
# 2  usarmy.jblm.medcom-mamc.mbx.t2products@mail.mil
# 3                              support@breethe.com
# 4                                 android@calm.com
#
#                               developerWebsite  \
# 0                     http://www.aurahealth.io
# 1                   https://www.betterhelp.com
# 2  http://t2health.dcoe.mil/apps/breathe2relax
# 3                     https://www.breethe.com/
# 4                          http://www.calm.com
#
#                                     developerAddress  \
# 0  2 Embarcadero Center, Fl 8\nSan Francisco, CA ...
# 1                                                NaN
# 2                                                NaN
# 3      754 des Fauvettes\nLongueuil, Quebec\nJ4G 2L6
# 4  140 2nd Street\n3rd Floor\nSan Francisco\nCA 9...
#
#                                        privacyPolicy  developerInternalID  \
# 0          https://www.aurahealth.io/privacy-policy/  8194778368040078712
# 1                 https://www.betterhelp.com/privacy  8471454122300503722
# 2  https://www.health.mil/Military-Health-Topics/...  5298048485350465783
# 3            https://main.breethe.com/privacy-policy  8674892394401317407
# 4                        http://www.calm.com/privacy  6775342773831033959
#
#               genre             genreId  \
# 0  Health & Fitness  HEALTH_AND_FITNESS
# 1  Health & Fitness  HEALTH_AND_FITNESS
# 2  Health & Fitness  HEALTH_AND_FITNESS
# 3  Health & Fitness  HEALTH_AND_FITNESS
# 4  Health & Fitness  HEALTH_AND_FITNESS
#
#                                                 icon  \
# 0  https://play-lh.googleusercontent.com/xMwzEkyE...
# 1  https://play-lh.googleusercontent.com/fdCP2dFi...
# 2  https://play-lh.googleusercontent.com/blgBoxuR...
# 3  https://play-lh.googleusercontent.com/lBeI58Av...
# 4  https://play-lh.googleusercontent.com/S76GphUu...
#
#                                          headerImage  \
# 0  https://play-lh.googleusercontent.com/MM9yM7r1...
# 1  https://play-lh.googleusercontent.com/96QFQfn1...
# 2  https://play-lh.googleusercontent.com/kPd9Pcmx...
# 3  https://play-lh.googleusercontent.com/9Vw5goUV...
# 4  https://play-lh.googleusercontent.com/16wOhncm...
#
#                                          screenshots  \
# 0  ['https://play-lh.googleusercontent.com/IEVbR6...
# 1  ['https://play-lh.googleusercontent.com/b77_ZD...
# 2  ['https://play-lh.googleusercontent.com/0O0Qu2...
# 3  ['https://play-lh.googleusercontent.com/dvlZ3l...
# 4  ['https://play-lh.googleusercontent.com/LPSOSs...
#
#                                                video  \
# 0                                                NaN
# 1  https://www.youtube.com/embed/b4KMB7mnlJw?ps=p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          videoImage contentRating  \
# 0                                               NaN      Everyone
# 1  https://i.ytimg.com/vi/b4KMB7mnlJw/hqdefault.jpg      Everyone
# 2                                               NaN      Everyone
# 3                                               NaN      Everyone
# 4                                               NaN      Everyone
#
#   contentRatingDescription adSupported  containsAds      released     updated  \
# 0                      NaN         NaN        False  Mar 21, 2017  1605694888
# 1                      NaN         NaN        False  Nov 17, 2014  1616437130
# 2                      NaN         NaN        False  Oct 24, 2011  1610041510
# 3                      NaN         NaN        False  Jan 25, 2016  1614090448
# 4                      NaN         NaN        False  Jul 30, 2014  1615619475
#
#               version                                      recentChanges  \
# 0               2.4.2                                                NaN
# 1                1.64  Thank you for using BetterHelp! We are constan...
# 2               4.0.0  App has been migrated to our Defense Health Ag...
# 3               5.3.2  Create your own playlists and download tracks ...
# 4  Varies with device  Thanks for using Calm! This update contains mu...
#
#                                    recentChangesHTML  editorsChoice  \
# 0                                                NaN          False
# 1  Thank you for using BetterHelp! We are constan...          False
# 2  App has been migrated to our Defense Health Ag...          False
# 3  Create your own playlists and download tracks ...          False
# 4  Thanks for using Calm! This update contains mu...           True
#
#                         appId  \
# 0              com.aurahealth
# 1              com.betterhelp
# 2  org.t2health.breathe2relax
# 3          com.Meditation.app
# 4            com.calm.android
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...

# %%
as_apps = pd.read_csv('Data/app_store_info.csv')
as_apps.head()
# Out:
#                         _id  \
# 0  605a2105fa456042d0948f3e
# 1  605a2105fa456042d0948f3f
# 2  605a2105fa456042d0948f40
# 3  605a2105fa456042d0948f41
# 4  605a2105fa456042d0948f42
#
#                                       screenshotUrls  \
# 0  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                   ipadScreenshotUrls  appletvScreenshotUrls  \
# 0  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 1  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 3  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                    NaN
# 4                                                NaN                    NaN
#
#                                         artworkUrl60  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artworkUrl512  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artworkUrl100  \
# 0  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 1  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 2  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#                                        artistViewUrl  \
# 0  https://apps.apple.com/nl/developer/aloebud-ll...
# 1  https://apps.apple.com/nl/developer/aura-healt...
# 2  https://apps.apple.com/nl/developer/betterhelp...
# 3  https://apps.apple.com/nl/developer/national-c...
# 4  https://apps.apple.com/nl/developer/breathwork...
#
#                                     supportedDevices  \
# 0  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 1  iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 2  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
# 3  iPad2Wifi-iPad2Wifi,iPad23G-iPad23G,iPhone4S-i...
# 4  iPhone5s-iPhone5s,iPadAir-iPadAir,iPadAirCellu...
#
#                                    advisories  isGameCenterEnabled      kind  \
# 0                                         NaN                 True  software
# 1                                         NaN                False  software
# 2  Soms/Milde medische/behandelingsinformatie                False  software
# 3                                         NaN                False  software
# 4                                         NaN                False  software
#
#                   features  minimumOsVersion               trackCensoredName  \
# 0  gameCenter,iosUniversal              11.0                        Aloe Bud
# 1             iosUniversal               9.0        Aura: Meditation & Sleep
# 2             iosUniversal              12.0  BetterHelp - Online Counseling
# 3             iosUniversal               9.0                   Breathe2Relax
# 4                      NaN              13.0  Breathwrk: Breathing Exercises
#
#   languageCodesISO2A  fileSizeBytes                     sellerUrl  \
# 0                 EN       16335872            http://aloebud.com
# 1                 EN      217529344      http://www.aurahealth.io
# 2                 EN       34968576    https://www.betterhelp.com
# 3                 EN       39609344  http://www.t2health.dcoe.mil
# 4                 EN       86342656                           NaN
#
#   formattedPrice contentAdvisoryRating  averageUserRatingForCurrentVersion  \
# 0         Gratis                    4+                             4.61538
# 1         Gratis                    4+                             4.49554
# 2         Gratis                   12+                             4.61904
# 3         Gratis                    4+                             4.83333
# 4         Gratis                    4+                             4.71950
#
#    userRatingCountForCurrentVersion  averageUserRating  \
# 0                                52            4.61538
# 1                               224            4.49554
# 2                                42            4.61904
# 3                                 6            4.83333
# 4                               164            4.71950
#
#                                         trackViewUrl trackContentRating  \
# 0  https://apps.apple.com/nl/app/aloe-bud/id13183...                 4+
# 1  https://apps.apple.com/nl/app/aura-meditation-...                 4+
# 2  https://apps.apple.com/nl/app/betterhelp-onlin...                12+
# 3  https://apps.apple.com/nl/app/breathe2relax/id...                 4+
# 4  https://apps.apple.com/nl/app/breathwrk-breath...                 4+
#
#             releaseDate     trackId                       trackName  \
# 0  2018-04-25T07:00:00Z  1318382054                        Aloe Bud
# 1  2016-10-11T02:56:47Z  1114223104        Aura: Meditation & Sleep
# 2  2015-07-11T02:30:33Z   995252384  BetterHelp - Online Counseling
# 3  2011-03-22T20:13:41Z   425720246                   Breathe2Relax
# 4  2019-11-14T08:00:00Z  1481804500  Breathwrk: Breathing Exercises
#
#                                     sellerName  primaryGenreName   genreIds  \
# 0                                  Aloebud LLC  Health & Fitness  6013,6012
# 1                             Aura Health Inc.  Health & Fitness  6013,6012
# 2                                Compile, Inc.  Health & Fitness  6013,6012
# 3  National Center for Telehealth & Technology  Health & Fitness  6013,6020
# 4                              Breathwork Inc.  Health & Fitness       6013
#
#    isVppDeviceBasedLicensingEnabled currentVersionReleaseDate  \
# 0                              True      2020-06-25T21:20:25Z
# 1                              True      2021-03-19T02:14:42Z
# 2                              True      2021-01-26T17:09:00Z
# 3                              True      2018-05-21T17:15:00Z
# 4                              True      2021-03-20T05:10:50Z
#
#                                         releaseNotes  primaryGenreId currency  \
# 0  iOS 13 Support\nRate the App prompt\nSound Eff...            6013      EUR
# 1  Thank you for using Aura! This update contains...            6013      EUR
# 2  Thank you for using BetterHelp! We are constan...            6013      EUR
# 3  You can now take advantage of your Apple Watch...            6013      EUR
# 4  Thank you for breathing with us. \nThis versio...            6013      EUR
#
#   version wrapperType    artistId  \
# 0     1.1    software  1170681391
# 1  3.11.6    software  1042329742
# 2     9.9    software   995252383
# 3   1.7.7    software   499648345
# 4   5.0.3    software  1481804499
#
#                                     artistName  \
# 0                                  Aloebud LLC
# 1                             Aura Health Inc.
# 2                                   BetterHelp
# 3  National Center for Telehealth & Technology
# 4                              Breathwork Inc.
#
#                               genres  price  \
# 0    Gezondheid en fitness,Lifestyle    0.0
# 1    Gezondheid en fitness,Lifestyle    0.0
# 2    Gezondheid en fitness,Lifestyle    0.0
# 3  Gezondheid en fitness,Geneeskunde    0.0
# 4              Gezondheid en fitness    0.0
#
#                                          description  \
# 0  Aloe Bud is your all-in-one, self-care pocket ...
# 1  ** As loved by Apple (Best of 2017, #1 New App...
# 2  BetterHelp is the convenient way to get profes...
# 3  Breathe2Relax is a portable stress management ...
# 4  Breathwrk guides you through quick and powerfu...
#
#                               bundleId  userRatingCount
# 0                       club.aloe.Aloe               52
# 1                       com.AuraMobile              224
# 2  com.ionicframework.betterhelp369708               42
# 3         org.t2health.BreatheTwoRelax                6
# 4                    com.breathwrk.ios              164

# %% [markdown]
# ### Google Play Reviews

# %%
gp_rvws = pd.read_csv('Data/google_play_rvws.csv')
gp_rvws.head()
# Out:
#                                             reviewId           userName  \
# 0  gp:AOqpTOGEfB5SuxUR45DJRzXJ13FFXszz7sHe0-EHZg9...       Melanie Loya
# 1  gp:AOqpTOEN7u1-0qBPlPuUQOydnhZucb7zs5I4edD6-7r...          Deb Perez
# 2  gp:AOqpTOHckNKYL0-HbSxg7mzO7YjQJ73fGmlpcW-H4uX...         Zvon Davis
# 3  gp:AOqpTOHx1iKm-H5IA8Rn7GDMz72FNxb2SHEJs0HcKkA...  Mary Ellen Gambon
# 4  gp:AOqpTOGA3muyUwk8gsdm92NYEy4R9L88BGaJLaC571U...       Amie Sandlin
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/-jQ70Y4S...
# 2  https://play-lh.googleusercontent.com/-cjE-8ul...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0                                            Awesome      5              0
# 1                              Great to help u sleep      5              0
# 2                             Very calming, love it!      5              0
# 3  I was able to sleep like a baby on the first u...      5              0
# 4        Improvement in thoughts, feelings and life!      5              0
#
#   reviewCreatedVersion                   at  \
# 0                2.4.2  2021-03-22 05:59:22
# 1                2.4.2  2021-03-21 20:29:44
# 2                2.4.2  2021-03-21 09:17:13
# 3                2.4.2  2021-03-21 09:09:57
# 4                2.4.2  2021-03-20 16:28:42
#
#                                         replyContent            repliedAt  \
# 0  Thanks for taking out time to rate us. It real...  2021-03-23 20:30:23
# 1  Thank you for your feedback. Glad to hear that...  2021-03-23 20:29:17
# 2       Glad you like it! :) Thanks for your review!  2021-03-23 20:27:04
# 3  We are pleased that you enjoyed the app. If th...  2021-03-23 20:26:24
# 4  Thank you for your review. Enjoy using the app...  2021-03-23 20:30:04
#
#   app_name          app_id
# 0     Aura  com.aurahealth
# 1     Aura  com.aurahealth
# 2     Aura  com.aurahealth
# 3     Aura  com.aurahealth
# 4     Aura  com.aurahealth

# %%
gp_rvws.duplicated(subset=['reviewId']).sum() # no duplicates
# Out:
# 0

# %%
gp_rvws.duplicated(subset=['userName', 'content', 'app_name']).sum()
# Out:
# 1579

# %%
gp_dupl = gp_rvws.loc[gp_rvws.duplicated(subset=['userName', 'content', 'app_name'],
                                         keep=False)].copy()
gp_dupl.head()
# Out:
#                                                reviewId       userName  \
# 1430  gp:AOqpTOEIDkzE-DotBobZMZoLf9nceMuGfpJuojNvhr3...  A Google user
# 1443  gp:AOqpTOG9s-yAidZ08avS7-1PVnPFU3dtS8VMBf9qLJG...  A Google user
# 1451  gp:AOqpTOEOCtFQMeTFtEQOZSlaZ_86RoVskY_RZNuqT8H...  A Google user
# 1558  gp:AOqpTOEBNbwiPwDC3vEReI1ZNXZwzeX8lasEhhQQ-xN...  A Google user
# 1599  gp:AOqpTOFkj3rt0dCx7czF55paF-CGnNBZxxPwUb0m2Bc...  A Google user
#
#                                               userImage    content  score  \
# 1430  https://play-lh.googleusercontent.com/EGemoI2N...      great      5
# 1443  https://play-lh.googleusercontent.com/EGemoI2N...  great app      5
# 1451  https://play-lh.googleusercontent.com/EGemoI2N...       good      4
# 1558  https://play-lh.googleusercontent.com/EGemoI2N...       good      5
# 1599  https://play-lh.googleusercontent.com/EGemoI2N...  great app      5
#
#       thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 1430              0                 0.44  2019-03-21 21:09:15          NaN
# 1443              0                 0.44  2019-03-18 07:24:08          NaN
# 1451              0                 0.44  2019-03-14 00:38:47          NaN
# 1558              0                 0.44  2019-02-16 11:01:36          NaN
# 1599              0                 0.44  2019-02-08 05:51:43          NaN
#
#      repliedAt app_name          app_id
# 1430       NaN     Aura  com.aurahealth
# 1443       NaN     Aura  com.aurahealth
# 1451       NaN     Aura  com.aurahealth
# 1558       NaN     Aura  com.aurahealth
# 1599       NaN     Aura  com.aurahealth

# %%
gp_dupl['content'].nunique()
# Out:
# 219

# %%
gp_dupl['content'].value_counts().to_frame()
# Out:
#                                           content
# Good                                          140
# Love it                                       128
# Great app                                      96
# Awesome                                        95
# Great                                          82
# Amazing                                        81
# Nice                                           73
# I love it                                      69
# good                                           49
# Very helpful                                   44
# Love it!                                       40
# love it                                        38
# Great app!                                     37
# I love this app                                34
# Good app                                       34
# Helpful                                        32
# Nice app                                       31
# Awesome app                                    29
# great                                          28
# Amazing app                                    27
# Excellent                                      23
# great app                                      21
# awesome                                        21
# Very good                                      19
# amazing                                        19
# I like it                                      19
# Easy to use                                    18
# Cool                                           17
# Love this app                                  17
# nice                                           16
# Best app                                       15
# Awesome!                                       14
# Perfect                                        13
# Brilliant                                      12
# Very relaxing                                  12
# Great!                                         12
# Fabulous                                       12
# Relaxing                                       11
# Loved it                                       11
# Wonderful                                      11
# Excellent!                                     10
# good app                                       10
# Amazing!                                        9
# Great App                                       9
# Easy to use.                                    8
# Wow                                             8
# It's great                                      7
# relaxing                                        7
# Best app ever                                   7
# excellent                                       7
# Love this app!                                  7
# Very good app                                   7
# Pretty good                                     6
# Its great                                       6
# Very useful                                     6
# Awsome                                          6
# love it!                                        6
# Great app.                                      6
# Its amazing                                     6
# Superb                                          6
# I loved it                                      6
# The best                                        6
# Very nice                                       6
# I love it!                                      5
# So far so good.                                 5
# Lovely app                                      5
# Love                                            5
# helpful                                         5
# Thanks                                          5
# Meditation                                      5
# Life changing                                   5
# It's amazing                                    5
# Love it.                                        5
# I like it.                                      5
# nice app                                        5
# awesome app                                     5
# Best                                            5
# Super                                           5
# Lovely                                          4
# Calm                                            4
# Amazing.                                        4
# It works                                        4
# Good stuff                                      4
# So far so good                                  4
# Fantastic                                       4
# very helpful                                    4
# Very motivating                                 4
# Very helpful!                                   4
# It's ok                                         4
# Ok                                              4
# perfect                                         4
# Bad                                             4
# Really helps                                    3
# Amazing app!                                    3
# love this app                                   3
# Very easy to use                                3
# Too expensive                                   3
# So far so good!                                 3
# Wonderful app                                   3
# Best meditation app                             3
# It's fabulous!                                  3
# too expensive                                   3
# Nice.                                           3
# I love this app.                                3
# Okay                                            3
# Really helpful                                  3
# Easy to use!                                    3
# Helps me sleep                                  3
# very relaxing                                   3
# AMAZING                                         3
# Worst app                                       2
# Awesome App!                                    2
# life changing                                   2
# It is really good                               2
# Like it                                         2
# Easy to use and helpful.                        2
# I love the sleep stories.                       2
# Really calming                                  2
# It is so cool                                   2
# Really nice                                     2
# pretty cool                                     2
# Cool app                                        2
# Very relaxing!                                  2
# I just love this app                            2
# Great stuff                                     2
# gr8                                             2
# very good                                       2
# Love the sleep stories!                         2
# 👍👍👍👍                                            2
# So helpful                                      2
# calm                                            2
# Help                                            2
# Very helpful app                                2
# Loved it!                                       2
# It's awesome                                    2
# Really fabulous                                 2
# Love love love                                  2
# I love this                                     2
# It's great.                                     2
# like it                                         2
# Perfect app                                     2
# Its awesome                                     2
# Thank u                                         2
# Great for tracking moods and activities.        2
# Pretty cool                                     2
# Love it. Thank you                              2
# Wonderful!                                      2
# Good job                                        2
# I hate it                                       2
# Love this app.                                  2
# It is amazing                                   2
# Loving it                                       2
# Thank you                                       2
# Osm                                             2
# The best!                                       2
# Great mood tracker                              2
# 👍                                               2
# Really good app                                 2
# One day at a time                               2
# I LOVE IT                                       2
# User friendly                                   2
# Love the app                                    2
# Very motivating!                                2
# I like this app                                 2
# Not bad                                         2
# Very nice app                                   2
# Good one                                        2
# Love the quotes                                 2
# I love this app!                                2
# great app!                                      2
# great app.                                      2
# This app is amazing                             2
# Amazing!!                                       2
# Good mood tracker                               2
# It's really good                                2
# i love it so much                               2
# very nice                                       2
# It's a very nice app                            2
# Calms my mind                                   2
# &lt;3                                           2
# Effective                                       2
# Awesome.                                        2
# The best app ever                               2
# bad                                             2
# Life changing.                                  2
# Rubbish                                         2
# Quick and easy                                  2
# Great motivation                                2
# Excellent.                                      2
# terrible                                        2
# Cool !!                                         2
# So easy to use                                  2
# I love it!!                                     2
# Wonderful app.                                  2
# Its fabulous                                    2
# Beautiful.                                      2
# Grt app                                         2
# It really works.                                2
# wonderful app                                   2
# Simple and easy to use.                         2
# It really helped me                             2
# Helpful.                                        2
# Very interesting                                2
# Peaceful                                        2
# i love it                                       2
# Fabulous!                                       2
# Osm app                                         2
# Amazing app.                                    2
# It's good                                       2
# It good                                         2
# This app sucks                                  2
# Good!                                           2
# Perfect for me                                  2
# Soothing                                        2
# This app is awesome                             2
# Fantastic app                                   2
# Useful                                          2
# Exceptional                                     2
# Kool                                            2

# %%
gp_rvws['content'].value_counts().to_frame().head(250)
# Out:
#                           content
# Good                         1802
# Love it                      1640
# Great app                    1544
# Great                        1457
# Awesome                      1245
# Amazing                      1048
# Nice                          777
# Very helpful                  631
# I love it                     612
# Love it!                      594
# Good app                      574
# good                          535
# Excellent                     533
# Helpful                       510
# Great app!                    484
# love it                       437
# Nice app                      414
# great                         402
# great app                     375
# I love this app               360
# Great!                        332
# Love this app                 325
# Very good                     320
# Amazing app                   317
# Awesome app                   295
# Relaxing                      292
# awesome                       272
# Cool                          266
# So far so good                263
# amazing                       259
# Wonderful                     257
# I like it                     228
# Loved it                      228
# Perfect                       220
# Love this app!                219
# Easy to use                   208
# nice                          203
# Amazing!                      199
# Fabulous                      195
# Awesome!                      192
# Great app.                    191
# Fantastic                     160
# good app                      160
# Life changing                 158
# Ok                            158
# Very relaxing                 157
# Brilliant                     151
# Best                          147
# very helpful                  142
# Calming                       142
# 👍                             142
# I love this app!              141
# Really helpful                141
# Love it.                      139
# Very good app                 139
# Great App                     136
# It's good                     135
# Best app ever                 134
# excellent                     131
# I love it!                    128
# Very nice                     125
# helpful                       124
# Very useful                   123
# Excellent app                 122
# Best app                      120
# love this app                 116
# It's great                    111
# Too expensive                 109
# Excellent!                    109
# Really good                   101
# Love                          100
# nice app                      100
# Thank you                      96
# Useful                         96
# Not free                       90
# Wow                            89
# Lovely                         88
# Very helpful.                  87
# Cool app                       86
# Amazing app!                   86
# Superb                         86
# It's amazing                   85
# Beautiful                      84
# Awesome app!                   83
# love it!                       83
# The best                       83
# Love this app.                 82
# very good                      81
# Awsome                         81
# So far so good.                81
# I love this app.               80
# Its good                       79
# It helps                       78
# cool                           76
# i love it                      75
# awesome app                    75
# Peaceful                       75
# wonderful                      75
# Pretty good                    74
# Wonderful app                  73
# Super                          71
# Very helpful!                  70
# so far so good                 69
# Calm                           68
# Good so far                    68
# Very nice app                  67
# Love it!!                      67
# great!                         67
# Bad                            67
# Love this                      65
# Amazing.                       64
# Fun                            64
# I love it.                     64
# great app!                     64
# Easy to use.                   61
# relaxing                       61
# Life changing.                 60
# Wonderful!                     60
# So far so good!                59
# Expensive                      59
# Exceptional                    58
# Best meditation app            58
# I like it.                     57
# It's awesome                   57
# Good one                       56
# Its great                      55
# Great App!                     55
# Great.                         54
# Very calming                   52
# amazing app                    52
# perfect                        52
# So helpful                     51
# AMAZING                        51
# It really helps                51
# Love it!!!                     50
# Like it                        50
# Fantastic app                  50
# Meditation                     50
# Great so far                   49
# Not bad                        49
# It works                       49
# ❤                              49
# So good                        48
# very relaxing                  48
# Thanks                         48
# Amazing app.                   48
# Great app!!                    48
# Good stuff                     48
# ok                             47
# Really helps                   47
# Very helpful app               47
# i love this app                46
# Fabulous!                      46
# Excellent.                     45
# It's helpful                   45
# It's really helpful            45
# ❤️                             45
# Good app.                      45
# Interesting                    45
# Loving it                      43
# This app is amazing            43
# Awesome.                       43
# life changing                  43
# Fantastic!                     43
# Awesome app.                   43
# love                           43
# Life changing!                 42
# excellent app                  42
# Useless                        42
# Incredible                     42
# I like this app                42
# I loved it                     41
# Its amazing                    41
# It's cool                      41
# Good.                          41
# Amazing!!                      41
# very nice                      41
# It's a great app               40
# Great experience               40
# Very useful app                40
# love this app!                 40
# 👌                              40
# Thank you.                     39
# Brilliant app                  39
# I love this                    38
# fantastic                      37
# Great meditation app           37
# easy to use                    36
# Really good app                36
# fabulous                       36
# Its awesome                    36
# Changed my life                36
# Love the app                   36
# Thank you!                     35
# It's very helpful              35
# Good App                       35
# Excellent app!                 35
# loved it                       35
# Nice!                          34
# It's nice                      34
# Inspiring                      34
# Great app!!!                   34
# thank you                      33
# very good app                  33
# The best!                      33
# Excellent app.                 32
# Soothing                       32
# Beautiful app                  32
# Love this app!!                31
# Meh                            31
# 😍                              31
# very useful                    31
# Helpful.                       31
# Very Helpful                   31
# Loved it!                      31
# Its cool                       31
# Fab                            31
# Great app for meditation       31
# Nice one                       31
# too expensive                  31
# It's great!                    30
# Awesome!!                      30
# Simple and effective           30
# Motivating                     30
# not free                       30
# i like it                      30
# its great                      29
# Very easy to use               29
# calming                        29
# It's a good app                29
# Brilliant!                     29
# really helpful                 29
# Extremely helpful              29
# Pretty cool                    29
# Lovely app                     29
# Perfect!                       29
# best app                       28
# Helpful!                       28
# best app ever                  28
# Helps alot                     28
# It's really good               28
# Its nice                       28
# Awesomeness                    27
# very calming                   27
# its good                       27
# It helps a lot                 27
# Helpful app                    27
# awesome!                       27
# the best                       27
# Nice app.                      27

# %%
gp_rvws['content'].value_counts().to_frame().tail(250)
# Out:
#                                                     content
# some of the peoplle on their are really mean th...        1
# So much variety!                                          1
# For someone who needs a 'listening ear' yet can...        1
# I love the app! Ive been looking for an app lik...        1
# Use this app personally and clinically as part ...        1
# Its awesome,hope  to transform me!!!                      1
# Brilliant idea deserves 5 stars for using game ...        1
# Nice app. I am learning a lot. And it's fun too.          1
# Sadly I can't give a negative star. Something t...        1
# Good and useful app!                                      1
# I don't like this app                                     1
# I like being able to start my day with the medi...        1
# Simple, easy to use, not packed with unnecessar...        1
# Sooo what I've been looking for!!                         1
# Could not have started meditating without this ...        1
# I like the tracker the best. Makes it easier to...        1
# Works for me and guides me through a useful pro...        1
# Use this app and you will know why it's name is...        1
# great it helpe me im in middle school and i am ...        1
# Great app, and great content. As someone with e...        1
# Only used it a short time and making new habits!          1
# this is a good app if you want theripy from ai,...        1
# Love this app. Easy, accessible and so good for...        1
# It's really motivational and I think I will ben...        1
# Good. Needs internal volume for speech versus s...        1
# No, I do not meditate that much in the first pl...        1
# Calm to me is a great app. You won't regret giv...        1
# Love the app, love the coaches and courses a es...        1
# 💙 this application is great                               1
# Amazing and helpful app                                   1
# What a disgusting app with worst theme ever               1
# Useless without money, I do understand that do ...        1
# I really enjoy the stories. They help me fall a...        1
# Everything about it just makes sense my whole l...        1
# I was very depressed in the beginning. I even t...        1
# It makes mindfulness meditation simple & access...        1
# Best medtation app I have ever seen                       1
# I never write reviews for apps. But this app ha...        1
# Great app. The reminders everyday helps a lot             1
# Thanks its usefull🙂                                       1
# I like it because u can use a fingerprint to un...        1
# Caroline Martin, this app is a fantastic go to ...        1
# I love this app.  I only have one problem. I ca...        1
# Great app for learning about mindfulness. The l...        1
# ABSOLUTELY DISGUSTED!!! downloaded the app for ...        1
# Don't do it                                               1
# It keeps me in shape and shapes my mind. Its ve...        1
# Odd how quickly this actually became habit. I w...        1
# Really nice app for journaling without writing ...        1
# I installed this app after watching a TV commer...        1
# It really works! I was starting to lose hope th...        1
# Without Calm, I'd be a mess! Thank you Calm Team!         1
# Great app! I would definitely recommend this ap...        1
# I've enjoyed the guided deep breathing.                   1
# as promised.                                              1
# Beautiful interface, needs more meditations ple...        1
# Nothing else has worked, and believe me, I've b...        1
# I wish wysa had a voice and personality to make...        1
# It would be great if I could afford all of the ...        1
# Act like its free 7 day free trial then 70 for ...        1
# This app makes m changing habits easy. It works...        1
# the basic sessions are a lovely way to relax.             1
# Very helpful app! I often get stuck in my negat...        1
# It all just feels so personalised, it's amazing.          1
# The reminders are perfect for my daily health c...        1
# Pause stop and put the brain in the body                  1
# Best application for meditation learning and pr...        1
# Helps and motivate to build healthy habits that...        1
# I am having an easier time working through my p...        1
# Try it out, you'll find its worth it                      1
# This is my first experience with meditation and...        1
# GEM BUAT LAWAK DOANG, CURHAT UJUNG2 E TETEP DIS...        1
# I love daylio! It's quick and easy and helps me...        1
# Try harder                                                1
# Needed an app like this! So glad I found it               1
# This app has a useful selection of relaxation a...        1
# Havent done the full 14 days yet but so far is ...        1
# I have used this app to log 1700 meditation ses...        1
# Wonderful Sober App!  Thanks!                             1
# This app is everything I wanted in a meditation...        1
# Its helped me loads                                       1
# bringing on my track                                      1
# It's a great app. Has a lot of options! And I l...        1
# I give it a 4 because it gives you options on w...        1
# Only just starting out but really loving it, ve...        1
# No u. It told md my moms gay. Its stupid. UNO r...        1
# Great app for setting goals and making small goals        1
# Since my free trial period ended the app won't ...        1
# Super useful app, can't imagine my life without...        1
# Actually there is a difference between the user...        1
# I love it to see how I was yesterday to today             1
# I love this app🥰☺😊                                        1
# The idea behind the app is nice, though not tha...        1
# It helps me significantly. Despite it being an ...        1
# Beautiful app. You can tell a lot of work went ...        1
# Decent games and learning tools. AI could be be...        1
# I feel better everyday.                                   1
# Good to know it exist!                                    1
# This app helped me sleep so many nights. I woul...        1
# What a fantastic app                                      1
# This makes my life better                                 1
# Extremely useful for combating stress, anxiety,...        1
# The start was great but then it kind of became ...        1
# Good way to keep you updated about yourself..!            1
# ❤️❤️❤️❤️❤️❤️✌️✌️✌️✌️✌️✌️✌️✌️💲💲💲💲💲💲💲💲💹💹💹💹💹💹💹               1
# I've tried all the popular meditation apps, and...        1
# it's really good. but I don't like how much you...        1
# Everyone on it are really nice and helpful.               1
# For Starters, I'm purely downloading the app be...        1
# Good way to create a habit                                1
# The best motivation Nd life changing app and re...        1
# Stop the Ads now it's really annoying                     1
# It's helping me to get motivated again to get f...        1
# love fabulous                                             1
# Awesome app. It let's you walk your path with A...        1
# Its really great but messaging system its so bad          1
# I started teaching last year, and if you're a t...        1
# I have shunned traditional counselling for year...        1
# Never pegged myself as someone who would keep a...        1
# I suffer with Dysthyma and this app is wonderfu...        1
# It's good and use full but if you forget your p...        1
# I love the quotes gives me a positive outlook o...        1
# I can sleep🧖                                              1
# Awesome during a time of uncertainty....                  1
# Love this app and works well with kids. However...        1
# I've only been using this for a few days, and i...        1
# Easy. Love the visuals.                                   1
# This app is not what its cut out to be. Im disa...        1
# love it!! helps me sleep at night and meditate ...        1
# Creative                                                  1
# It's very expensive. After paying money you can...        1
# Helps you be accountable for 10 min of your day...        1
# I truly love this guided meditations app.                 1
# Thank you so very much! It's such a great suppo...        1
# I am happy to have this app to help me for stre...        1
# Great meditation app for the beginner and those...        1
# I have been using this app since 2012. I use it...        1
# Really quality app, good content. Adding new ha...        1
# Thank you for such a great designed meditation ...        1
# Love the customisability and that you can add n...        1
# I actually use it! Insight Timer has such a var...        1
# HELPED ME SO MUCH                                         1
# The atories are a breath away from sleeping! lo...        1
# Simple and easy to utilize immediately. Very ac...        1
# Love how the app gives you a monthly summary of...        1
# As soon as I got on, some creep asked me where ...        1
# It's great the only think i would like to add t...        1
# I'm using the free version and I have to say it...        1
# Pretty cool...makes me smile and is very intuitive        1
# It is Amazing app. I recommend to everyone to d...        1
# this app has changed my life. There are so many...        1
# You can't operate the app without first handing...        1
# if you're a paid app you should inform me befor...        1
# Love the train themed sleep stories!                      1
# Great benefits offered from my employer. Totall...        1
# I dont want to pay, I just want to sleep so ple...        1
# Its a super cool way to keep track of your day ...        1
# For the past week I've been trying to sign up, ...        1
# I have to uninstall the app because it doesn't ...        1
# It keeps my emotions on track. OuO)b                      1
# Fun to ues                                                1
# UX experience is very good. keep it up :)                 1
# Just awesome....can't live without it                     1
# Best soothing and calming app ever. Wonderful b...        1
# I've been using the app for 4 days and I can al...        1
# I love this💕 It keeps me motivated!                       1
# A wonderful addition to my day.                           1
# To be honest I can't explain how much I'm happy...        1
# App has been good so far. Motivates me each day...        1
# Love it, shine can always help me refocus and p...        1
# Simple, effective, and informative in how to ad...        1
# Absolutely LOVE it!!                                      1
# Informative app                                           1
# Very motivating app, I would recommend this to ...        1
# Paid for it.  And love it's features.                     1
# Used to really like it, but after switching pho...        1
# It's simple and to the point.                             1
# Really easy to maintain                                   1
# The best mindfulness app I've found.                      1
# They get 3 stars for refunding my money.                  1
# useful reminders, fun interactions. But don't g...        1
# Very calming and relaxed                                  1
# AWESOME APP! I can track how I feel with a few ...        1
# Just started, wait and see.                               1
# Effectively has already developed some good hab...        1
# seems like an useful application                          1
# Life changing app. Highly highly recommend it!            1
# Very good app. . One of the few app which i act...        1
# the most confusing app...                                 1
# Great app help me change                                  1
# Please allow immersive Google Home control. It'...        1
# The Waking Up app has provided immeasurable ben...        1
# IT'S VERY CALMING                                         1
# I can't sign up, I've tried at 3 different time...        1
# I really like the courses offered and you can s...        1
# Not only do I use it regularly, my kids (ages 7...        1
# Many different styles of meditation to choose f...        1
# It's a good way to keep track of own feelings. ...        1
# Wasn't sure at first but great app great support          1
# so far so good... impressed with the reminders ...        1
# Soo helpful!                                              1
# I'm actual getting all my feeling out to someon...        1
# I love this app. It's so easy to use and has ma...        1
# Loved it so much I bought the full version                1
# It is excellent for helping me with my Autism S...        1
# I have only been using the app a week but it is...        1
# You have to pay so that you get to enjoy most o...        1
# I love rainy day antiques, it's my favourite. T...        1
# But your price is off the charts insane.                  1
# Pretty good. I use for therapy reports. Recomme...        1
# not very good on my phone                                 1
# Omg... trying to cancel my subscription took 10...        1
# I love this app so much. It helped me go throug...        1
# Totally inspired by this app                              1
# Really enjoying the prompts and backup saving d...        1
# I've used the free form of this app for so long...        1
# I love it! Calm has help me release stress and ...        1
# Headspace is a wonderful app.                             1
# The reminders are extremely helpful! There are ...        1
# builds awareness                                          1
# Loving this new custom day start thing! Since I...        1
# Short and effective habits thst go a long way             1
# This app was great until now. It's crashing in ...        1
# Every release has great improvements. The level...        1
# Really great app that enables me to track my da...        1
# So far this is working really well just to trac...        1
# A cute quick way to document your day.                    1
# SECOND EDIT: The developers listened to my feed...        1
# Great motivational tool!                                  1
# Dailyo is quick & easy to use. Monitor a variet...        1
# auto renewal charged me $100                              1
# Useful and customizable.                                  1
# I really like this app it seems to be working. ...        1
# Does what it says, calm and then some...                  1
# Easy to use diary app.                                    1
# Great app, really motivating to see how far you...        1
# Loving, supportive people 💙                               1
# Very easy 2 use. Love it.                                 1
# Great easy to use app with lots of helpful feat...        1
# It would be better if app doesnt open after i c...        1
# An alternative to being relaxed without medicat...        1
# While there is technically a free version of th...        1
# Terrific app...I suffer from crps...a debilitat...        1
# This is a wonderful app. Helps me start my day ...        1
# Initially takes a bit of time to ease into it. ...        1
# Like its name, Fabulous!! Your apps design is p...        1
# There is room for improvement                             1
# Intrusive. Why should I register? That was irri...        1
# I really do love this app I'm just wondering af...        1
# Thank you!! Wonderful meditations                         1

# %%
gp_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421583 entries, 0 to 421582
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              421583 non-null  object
#  1   userName              421583 non-null  object
#  2   userImage             421583 non-null  object
#  3   content               421436 non-null  object
#  4   score                 421583 non-null  int64
#  5   thumbsUpCount         421583 non-null  int64
#  6   reviewCreatedVersion  373201 non-null  object
#  7   at                    421583 non-null  object
#  8   replyContent          52903 non-null   object
#  9   repliedAt             52903 non-null   object
#  10  app_name              421583 non-null  object
#  11  app_id                421583 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 38.6+ MB

# %%
gp_rvws.dropna(subset=['content'], inplace=True)

# %%
gp_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421436 entries, 0 to 421582
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              421436 non-null  object
#  1   userName              421436 non-null  object
#  2   userImage             421436 non-null  object
#  3   content               421436 non-null  object
#  4   score                 421436 non-null  int64
#  5   thumbsUpCount         421436 non-null  int64
#  6   reviewCreatedVersion  373065 non-null  object
#  7   at                    421436 non-null  object
#  8   replyContent          52900 non-null   object
#  9   repliedAt             52900 non-null   object
#  10  app_name              421436 non-null  object
#  11  app_id                421436 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 41.8+ MB

# %%
gp_rvws_slice = gp_rvws[['app_name', 'content', 'score', 'at']].copy()
gp_rvws_slice.columns = ['app_name', 'review', 'rating', 'date']
gp_rvws_slice['gp_rvw'] = 1
gp_rvws_slice
# Out:
#        app_name                                             review  rating  \
# 0          Aura                                            Awesome       5
# 1          Aura                              Great to help u sleep       5
# 2          Aura                             Very calming, love it!       5
# 3          Aura  I was able to sleep like a baby on the first u...       5
# 4          Aura        Improvement in thoughts, feelings and life!       5
# ...         ...                                                ...     ...
# 421578     Wysa                                           Loved it       5
# 421579     Wysa  Sometimes we just need a ear or sometimes the ...       5
# 421580     Wysa  Innovative thinking,... feeling good while int...       5
# 421581     Wysa                                      Great concept       5
# 421582     Wysa  App makes a difference, feels like I'm talking...       5
#
#                        date  gp_rvw
# 0       2021-03-22 05:59:22       1
# 1       2021-03-21 20:29:44       1
# 2       2021-03-21 09:17:13       1
# 3       2021-03-21 09:09:57       1
# 4       2021-03-20 16:28:42       1
# ...                     ...     ...
# 421578  2016-10-28 02:31:14       1
# 421579  2016-10-24 08:14:25       1
# 421580  2016-10-16 11:03:57       1
# 421581  2016-10-12 12:31:21       1
# 421582  2016-10-08 02:45:03       1
#
# [421436 rows x 5 columns]

# %% [markdown]
# ### App Store Reviews

# %%
as_rvws = pd.read_csv('Data/app_store_rvws.csv')
as_rvws.head()
# Out:
#                                               review  rating  \
# 0  I really am enjoying this app and once I start...       5
# 1  I have tried a lot of apps that said they woul...       5
# 2  IT JUST CAN'T GET MUCH BETTER! it really helps...       5
# 3  I don’t usually write reviews for apps, but I ...       5
# 4  Where to begin before I started using aloe bud...       5
#
#            userName                 date  isEdited  \
# 0            knsky8  2020-10-09 12:19:21     False
# 1  Candycrushgirl60  2021-03-01 03:51:42     False
# 2   hhhhhjghjhhnjgh  2021-03-13 01:16:42     False
# 3           ekg2005  2020-06-29 12:20:49     False
# 4   Shoshana Lipson  2020-06-26 21:38:49     False
#
#                                 title  app_name      app_id
# 0  Simple gentle ways to a better you  aloe-bud  1318382054
# 1           This app changed my life!  aloe-bud  1318382054
# 2          Love this app! - MOST READ  aloe-bud  1318382054
# 3           Such a cute, helpful app!  aloe-bud  1318382054
# 4                        So Amazing!!  aloe-bud  1318382054

# %%
as_rvws.duplicated(subset=['review', 'userName', 'app_name']).sum()
# Out:
# 0

# %%
as_rvws['userName'].value_counts()
# Out:
# N/A 1234          5
# The-Schwarz       4
# CaffeineKittt     3
# Kalioat           3
# Eyeless Fish      3
#                  ..
# Bffvfhysf         1
# tearoseindelhi    1
# ROSas🤣💧🤫          1
# nicknameejtera    1
# Lari Jones        1
# Name: userName, Length: 46874, dtype: int64

# %%
as_rvws['review'].value_counts().to_frame().head(250)
# Out:
#                              review
# Good                             88
# Love it                          82
# Great                            63
# Great app                        62
# I love this app                  52
# I love it                        51
# Amazing                          39
# I like it                        37
# :)                               31
# Very helpful                     31
# Awesome                          30
# Love it!                         30
# Hi                               24
# Love this app                    24
# good                             23
# Great!                           23
# Nice                             23
# Good app                         22
# Great app!                       21
# It’s great                       20
# Thank you                        18
# Love this app!                   18
# Yes                              16
# Amazing app                      15
# Very good                        15
# love it                          15
# It’s good                        14
# 👍                                13
# .                                13
# I love this app!                 13
# Cool                             13
# Awesome app                      12
# It’s a good app                  11
# great                            10
# Helpful                          10
# Yay                              10
# nice                              9
# Highly recommend                  9
# i love this app                   9
# I love it!                        9
# Thanks                            9
# Ok                                9
# good app                          9
# Best app ever                     8
# Amazing!                          8
# Very good app                     8
# Yeah                              8
# Thank you!                        8
# yes                               8
# Awesome app!                      8
# i love it                         8
# This app is amazing               8
# I love this                       8
# I                                 8
# So far so good                    8
# It’s a great app                  8
# It helps                          8
# ❤️                                8
# amazing                           8
# This app is amazing!              7
# great app                         7
# 10/10                             7
# Thank you.                        7
# Very calming                      7
# Very helpful!                     7
# Excellent                         7
# Love                              7
# Easy to use                       7
# Great App!                        7
# Love the app                      7
# It’s amazing                      7
# very helpful                      7
# Helps                             6
# I like this app                   6
# Really helpful                    6
# It helps a lot                    6
# Very nice                         6
# Love it.                          6
# Really helps                      6
# ❤️❤️❤️                            6
# Love this                         6
# I love it so much                 6
# awesome                           6
# ...                               6
# Wonderful                         5
# Love this app.                    5
# It really helps                   5
# This is a great app               5
# Too expensive                     5
# Helped me a lot                   5
# ❤️❤️                              5
# I really like this app!           5
# :D                                5
# very good                         5
# I love this app so much!          5
# It’s awesome                      5
# Ye                                5
# Idk                               5
# I love it!!!                      5
# Relaxing                          5
# 5 stars                           5
# Yep                               4
# Thanks!                           4
# 👍🏻                                4
# Five stars                        4
# Very helpful.                     4
# It helps me a lot                 4
# Cool app                          4
# It is a great app                 4
# Life changing                     4
# love this app                     4
# Good app.                         4
# App                               4
# It’s cool                         4
# ❤️❤️❤️❤️                          4
# I love this app so much           4
# Nice app                          4
# love                              4
# it’s good                         4
# I really love this app            4
# This app is awesome               4
# Not bad                           4
# I LOVE THIS APP                   4
# Great App                         4
# Perfect                           4
# I love this app!!                 4
# Pretty good                       4
# Love it so much                   4
# Very relaxing                     4
# Very convenient                   4
# I love this app.                  4
# hi                                3
# I like this app a lot             3
# This is a great app!              3
# ok                                3
# Would recommend!                  3
# Loving it so far                  3
# This app is very helpful          3
# 👍👍                                3
# Loved it                          3
# This                              3
# 😁                                 3
# 💕                                 3
# So far so good!                   3
# Helps me sleep                    3
# It’s okay                         3
# No                                3
# Great help                        3
# It helped me a lot                3
# love this app!                    3
# This is amazing                   3
# Helps me a lot                    3
# Solid                             3
# This is great                     3
# 👍🏼                                3
# Wow                               3
# It’s calming                      3
# So amazing                        3
# Easy to use!                      3
# it helps me                       3
# ⭐️⭐️⭐️⭐️⭐️                        3
# 😍                                 3
# Simple and effective              3
# Awesome!                          3
# <3                                3
# Helpful.                          3
# It’s the best                     3
# So good                           3
# Love this app so much             3
# Works                             3
# Helps a lot                       3
# Really good app                   3
# very nice app                     3
# Highly recommended                3
# It’s really calming               3
# Wonderful app!                    3
# Super helpful                     3
# 😊                                 3
# Ya                                3
# ..                                3
# Useful                            3
# It good                           3
# Very peaceful                     3
# lol                               3
# Yuh                               3
# I like it!                        3
# Great app!!!                      3
# Easy to use.                      3
# 💗                                 3
# It works                          3
# Happy                             3
# It works.                         3
# Loving it so far!                 3
# Yea                               3
# Love!                             3
# Pretty cool                       3
# It’s really helpful               3
# Great so far!                     3
# I love the app                    2
# Very user friendly                2
# It’s a amazing app                2
# It helps me with my anger         2
# Poop                              2
# So helpful                        2
# cool                              2
# Thank you!!                       2
# G o o d                           2
# Great app love it                 2
# I love it so far                  2
# So far, so good.                  2
# Good!                             2
# Best app ever!!                   2
# ^                                 2
# I love it.                        2
# This app is the best              2
# It                                2
# This app is great                 2
# I really like this app            2
# It helped me                      2
# I love this it helps a lot        2
# It helps me calm down             2
# My favorite meditation app!       2
# Try it!                           2
# Good stuff                        2
# It has helped me a lot            2
# Really good                       2
# Best app                          2
# Just what I needed                2
# H                                 2
# Title says it all                 2
# So far so good.                   2
# I feel better                     2
# I really like it                  2
# Good start                        2
# Like it                           2
# yea                               2
# Interesting                       2
# 👍👍👍                               2
# Highly recommend.                 2
# This app is awesome!              2
# Lol                               2
# It is amazing                     2
# E                                 2
# I like the app                    2
# Thank you so much.                2
# so helpful                        2
# It’s very helpful                 2
# Absolutely love it                2
# i love it so much                 2
# It really helps me                2

# %%
as_rvws['review'].value_counts().to_frame().tail(250)
# Out:
#                                                     review
# It helps with stress and it just nice to have i...       1
# I don’t have the money or my parents and all th...       1
# Having a therapist at your fingertips is so hel...       1
# I think this is a great app for breathing work ...       1
# This app is great and worth every penny. I fina...       1
# Most of the features are locked and it’s too ex...       1
# I can actually express my feelings and I can le...       1
# It really helps my body relax as my mind is ful...       1
# It’s really helpful. I’ve struggled with addict...       1
# Helps me get into the right more or just relax ...       1
# Purchased the 3 month deal for a 30 minute meet...       1
# I only had it for two days and I feel way bette...       1
# Kaiser got me to get the app subscription, and ...       1
# Found you guys on tiktok and downloaded! I love...       1
# My issue isn’t so much the app itself, that’s f...       1
# first day, will update soon                              1
# It’s a great useful app but I am honestly so bu...       1
# If you’re struggling with feeling alone or know...       1
# The new update got rid of all my other moments ...       1
# I love the maneuvering of this app. Setting thi...       1
# I usually don’t rate apps but this is phenomena...       1
# I’ve been depressed for about 2 years now, I ju...       1
# The default payment charged me for 1 year by de...       1
# If you are searching for some help to become a ...       1
# Should have downloaded sooner it’s my go to for...       1
# I’ve never written a review for an app but i’ve...       1
# This is an amazing app, it helps me fall asleep...       1
# This is my favorite mediation app I’ve tried so...       1
# Made me purchase a subscription every month and...       1
# Calm tries very hard to cater to the emotional ...       1
# Please get this app if you are struggling menta...       1
# I downloaded the app enjoyed it for one day the...       1
# I got this app for its sleep stories, and I spe...       1
# I don’t need between 6-10 notifications every d...       1
# Really is a game changer when you go all in wit...       1
# I love this app so much I 😍😍😍😍❤️❤️❤️❤️❤️❤️❤️❤️❤...       1
# This is a good app so I started filling out mh ...       1
# I fell way more confident than I have in a long...       1
# I’d just like to say, I got this app 14 days ag...       1
# I have been signed up for weeks now and still h...       1
# I like the app, I think it’s a really good tool...       1
# this app is helpful and calming!                         1
# this app shouldn’t even be free if half the thi...       1
# During times of world issues, personal, grievin...       1
# This app is amazing. I highly recommend.                 1
# I think it’s an amazing app, and it will help m...       1
# This app is really nice because, like the name,...       1
# Great app. Easy to use. It’s nice in the messag...       1
# I don’t want to pay for things but I have to pa...       1
# So I think it’s good cuz I’m currently waiting ...       1
# It is my favorite story on calm it is amazing b...       1
# BetterHelp has been great for me, especially du...       1
# I am enjoying the app very much. It asks really...       1
# it really helps calm u down , sleep well and ev...       1
# I absolutely love this app. I started using Woe...       1
# Sam lays out the basics of meditation while cat...       1
# Oh the greed! Nothing here is for free!! NOTHIN...       1
# Good I can write down my feelings and it makes ...       1
# I downloaded Calm because my dad died I an acci...       1
# As a meditation app Headspace is awesome! I lov...       1
# This app is awesome, and I am glad to use it, b...       1
# Let’s me write out my thoughts, and has nice le...       1
# Love this app! Most structured approach to medi...       1
# Keeps me focused with daily check ins                    1
# I have been using and getting to know how to us...       1
# I bought a year and regret it.\nHeadspace is fa...       1
# Love this app! I was eager for a tool to help m...       1
# I joined 10 Percent 1 year ago. It has been my ...       1
# I was looking forward to trying this app unfort...       1
# Great app for an online personal journal.                1
# I recommend this app for anyone who loves writi...       1
# Very good helped me sleep                                1
# Hard to use this app to get to sleep when it ca...       1
# I just recently starting using this app and hav...       1
# I love this app Bc it keeps track and gives you...       1
# Overall I like the app and it helps me cope wit...       1
# The male voice grated on my nerves. I always ch...       1
# BetterHelp is extremely affordable and convenie...       1
# Having someone you can go to with an urgent mes...       1
# This app used to be really good, but now EVERYT...       1
# The app is made to feel like AI, and you get to...       1
# Best app there is for staying motivated                  1
# Thank you...I needed that 🙏🏻🧘🏻‍♀️                        1
# Road Dog Dan                                             1
# I was having trouble sleeping so I used this ap...       1
# Love the app on my phone but the iPad app lacks...       1
# Shine has truly made a difference in my life. I...       1
# They tie your money, then upon asking for refun...       1
# Hello - I have been using 10% Sleep Routines to...       1
# This app is really awesome, and I can really ge...       1
# Was looking for an app around CBT and found thi...       1
# I wanted to see what this app was all about. I ...       1
# At first I thought it would be a sucky app. And...       1
# It is ok but not amazing because everything is ...       1
# And my counselor!                                        1
# I love this app and it’s really relaxing and le...       1
# My goodness this has been a life changing exper...       1
# Headspace had great reviews so I was like let m...       1
# I cannot say enough good things about Sam. He u...       1
# After using for awhile, I've noticed it has two...       1
# Gave me the opportunity to express my mental an...       1
# I was afraid that using an app would go against...       1
# I wish there was another option with the check ...       1
# This app is perfect if you need to vent. It’s w...       1
# I’m tired of seeing Pharrell’s face pop up ever...       1
# I mean I really could not stick with anything, ...       1
# super                                                    1
# Good app even if you have just a little anxiety.         1
# It’s very calming just overall. it is really go...       1
# I only have the free version but I’m thinking o...       1
# I can’t live without this app. Beyond grateful.          1
# This is a great app 10/10 would recommend.               1
# I have tried and failed to get into meditation ...       1
# I just got the app and i can’t select challenges.        1
# Y’all r really helping me with my feeling I rat...       1
# So recently I’ve been having a hard time with l...       1
# So you need money to be happy? Wowwwww                   1
# Good meditation, but more talking than I felt w...       1
# When I first signed up I wasn’t sure if I shoul...       1
# Helped me so much with anxiety                           1
# My therapist own words I’ll never forget:\n“You...       1
# I love this app because I feel like I can talk ...       1
# It’s a really good app to write all your feelin...       1
# Not sure why my car was automatically charge wh...       1
# Excellent meditation app. My favorite thing abo...       1
# Reflectly is a really good app but I wish it wo...       1
# So creative and gentle- I feel as if I’ve enter...       1
# So far, I’ve really enjoyed the meditations fro...       1
# Helps me write out my thoughts and it’s a way t...       1
# I’ve been using this app for about 2 weeks now....       1
# Helped me get more in tune with my mind and ana...       1
# It’s bad. It makes you pay for everything.               1
# This app has short lessons on various technique...       1
# I love this app it stopped me from committing            1
# Learning to relieve my mind of external stimula...       1
# Always have someone to talk to                           1
# The first time is used the app after downloadin...       1
# Great app to build healthy habits until your da...       1
# So convenient and amazing.                               1
# Betterhelp has helped me tremendously. I encour...       1
# Plssssssss this app is amazing I sent screensho...       1
# Good does everything you need                            1
# Love it so much\nVery educational and helpful w...       1
# It’s like a calendar but better                          1
# 👋✋✋👋                                                     1
# This app is completely lovely. It is such a pos...       1
# Love app                                                 1
# I live Betterhelp and my counselor. I took a br...       1
# i’m already seeing a change in my happiness and...       1
# A meditation app with constant in-app purchases...       1
# This app helps me with  expressing my emotions           1
# How does anyone find the layers of side screens...       1
# It’s only been a couple weeks but the ability t...       1
# Better option than seeking out someone individu...       1
# I highly recommend this app you won’t regret it...       1
# Best tone, best practices, best courses The bes...       1
# A great way to monitor how my activities direct...       1
# This is a really good app it gives u quotes and...       1
# this app is actually really helpful.. because i...       1
# I got this app today and it helps a lot! You do...       1
# I’ve been using this app for a little under a w...       1
# this really helps me identify when i’m feeling ...       1
# Got it before it became a monthly thing so I’m ...       1
# Estoy aprendiendo a meditar descubriendo este m...       1
# i love this app it helps , and soothes me i sug...       1
# This fellow is calming, accepting, and so easy ...       1
# I think I love it because it lets me read what ...       1
# Once I had the app downloaded logging in and us...       1
# Love everything about this app, but wish you co...       1
# I really appreciated that I wasn’t “stuck” with...       1
# Love this app. Though after using it awhile it ...       1
# at first, wysa seemed like a very cool app. but...       1
# I think this app might be extremely useful but ...       1
# Little habits take you a long way so I apprecia...       1
# CALM is such a lovely tool to regain, or rememb...       1
# I was charged for a year subscription that I ne...       1
# This app was really helpful with a lot of probl...       1
# Sams wife annikka has amazing meditations for c...       1
# I hate how u have to pay im only a kid and ive ...       1
# After my first time, I was ready to get up in t...       1
# I have been listening to TPH for more than a ye...       1
# I like this app. I downloaded it a couple days ...       1
# Everything I’m going to write will be relevant ...       1
# Thank you I enjoy very mush                              1
# This is really good, but it won’t help me calm ...       1
# So far so good. Can see possibilities for posit...       1
# Everyone can use a mental health tune up every ...       1
# This is such a great app. And free? What else i...       1
# This is by far the best meditation app you will...       1
# I am not completely satisfied with the app but ...       1
# It’s super helpful just being able to vent anyt...       1
# I think it’s amazing, for me I can say what I w...       1
# I’ve been a user of Calm for just over a year a...       1
# I love Daylio. I purchased the premium version ...       1
# Don't be fooled!  It is an app that induces pay...       1
# I just got this app and I think it’s rad I don’...       1
# A couple dozen sessions in and I feel and see t...       1
# The free 3 phase breathing exercise was taken o...       1
# This app has great graphics and makes achieving...       1
# Really Great Quality no problems                         1
# My life isn’t the best and Reflectly is perfect...       1
# Have more than 4 choices of intensity                    1
# I just love it!😻everyone needs this to survive ...       1
# I was lucky enough to be matched with the thera...       1
# Simply amazing.                                          1
# I have been using this app for an hour and I on...       1
# Writing out my thoughts and shortcomings help.           1
# Suddenly removing essential features from the f...       1
# Woebot isn’t 100% perfect, just like the rest o...       1
# I have anxiety and depression, it make life har...       1
# Loved using Headspace for meditation as well as...       1
# I connect well with my counselor. We talking on...       1
# I like how it gives you an option to have unloc...       1
# This app is really good for helping me get my f...       1
# i really like this app because she really talks...       1
# This app has really changed how I manage my day...       1
# This app has changed my life ! I didn’t think I...       1
# Best investment in myself. I have gained so muc...       1
# Amazing tools to teach mindfulness, meditation ...       1
# I love the actual content of Headspace, but the...       1
# Have used for two days now the free trail. I fe...       1
# I work nights and am very thankful\nI can custo...       1
# This app is helping me see that I have the powe...       1
# I updated the app and now I don’t know where an...       1
# Love this game but almost all the activity’s ar...       1
# loving the fact that this helps me, even in the...       1
# The app is great and relaxing but before you in...       1
# I loveeeeeeeeeeeee hard space I really enjoy it...       1
# It’s really easy to use and understand, and giv...       1
# I absolutely love these stories!  If I fall asl...       1
# I’d like to be able to schedule off days  witho...       1
# Headspace has helped me so much with my sleep. ...       1
# I was assigned to a provider and was skeptical ...       1
# The app is awesome, I think it could use a few ...       1
# This is the best app I’ve seen in a while. Actu...       1
# The mighty app has helped me find a community a...       1
# Everything about this is beautiful, from the gr...       1
# use it everyday and helps me face problems it’s...       1
# Totally worth the time and money. It has helped...       1
# It is trash! This app doesn’t work at all. It d...       1
# Why does it require email verification every ti...       1
# La aplicación esta bien me suscribí pero me hic...       1
# Awesome👌👌👌💖☺️                                            1
# It really does calm me down so I think y’all sh...       1
# Ive been charged $38.99 and I haven’t completed...       1
# It has helped me get my thoughts out of my head...       1
# its just so great to put all my feelings down s...       1
# Moodpath has made my life much easier and I’m g...       1
# yeah i only came here to listen to harry 😛               1
# I like this app because it helps me relax at th...       1

# %%
as_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47321 entries, 0 to 47320
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   review    47319 non-null  object
#  1   rating    47321 non-null  int64
#  2   userName  47321 non-null  object
#  3   date      47321 non-null  object
#  4   isEdited  47321 non-null  bool
#  5   title     47320 non-null  object
#  6   app_name  47321 non-null  object
#  7   app_id    47321 non-null  int64
# dtypes: bool(1), int64(2), object(5)
# memory usage: 2.6+ MB

# %%
as_rvws.dropna(subset=['review'], inplace=True)

# %%
as_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47319 entries, 0 to 47320
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   review    47319 non-null  object
#  1   rating    47319 non-null  int64
#  2   userName  47319 non-null  object
#  3   date      47319 non-null  object
#  4   isEdited  47319 non-null  bool
#  5   title     47318 non-null  object
#  6   app_name  47319 non-null  object
#  7   app_id    47319 non-null  int64
# dtypes: bool(1), int64(2), object(5)
# memory usage: 2.9+ MB

# %%
as_rvws_slice = as_rvws[['app_id', 'review', 'rating', 'date']].copy()
as_rvws_slice
# Out:
#            app_id                                             review  rating  \
# 0      1318382054  I really am enjoying this app and once I start...       5
# 1      1318382054  I have tried a lot of apps that said they woul...       5
# 2      1318382054  IT JUST CAN'T GET MUCH BETTER! it really helps...       5
# 3      1318382054  I don’t usually write reviews for apps, but I ...       5
# 4      1318382054  Where to begin before I started using aloe bud...       5
# ...           ...                                                ...     ...
# 47316  1060691513  I’m typically loaded with piss and vinegar but...       5
# 47317  1060691513  Hi, I’ve been struggling with my BPD, depressi...       5
# 47318  1060691513  I would love to get premium so I can utilize t...       2
# 47319  1060691513  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 47320  1060691513  this app would be good to help me with my prob...       1
#
#                       date
# 0      2020-10-09 12:19:21
# 1      2021-03-01 03:51:42
# 2      2021-03-13 01:16:42
# 3      2020-06-29 12:20:49
# 4      2020-06-26 21:38:49
# ...                    ...
# 47316  2020-03-14 01:16:42
# 47317  2020-03-07 00:50:10
# 47318  2020-03-13 02:47:24
# 47319  2021-03-24 18:32:13
# 47320  2021-03-24 13:49:56
#
# [47319 rows x 4 columns]

# %%
as_name_map = {}
for app_id in app_df['as_id'].unique():
    value = app_df.loc[app_df['as_id']==app_id]['app_name'].to_list()[0]
    as_name_map[app_id] = value
as_name_map
# Out:
# {1318382054: 'Aloe Bud',
#  1114223104: 'Aura',
#  995252384: 'BetterHelp',
#  425720246: 'Breathe2Relax',
#  1481804500: 'Breathwrk: Breathing Exercises',
#  920161006: 'Breethe: Meditation & Sleep',
#  1450365119: 'Breeze: mood tracker, diary',
#  571800810: 'Calm',
#  1010391170: 'CBT Thought Diary',
#  1194023242: 'Daylio',
#  1452264969: 'DBT Coach',
#  1184456130: 'eMoods',
#  1318726049: 'eQuoo: Emotional Fitness Game',
#  1203637303: 'Fabulous',
#  1140486359: 'GG OCD',
#  1489604281: 'GG Self Care',
#  1300107718: 'GG Self Esteem',
#  515118602: 'Ginger',
#  994882113: 'Habitica',
#  730601963: 'Happify',
#  707073943: 'Happyfeed',
#  493145008: 'Headspace',
#  1326310617: 'Healthy Minds Program',
#  1417672401: 'HearMe',
#  672904239: 'I Am Sober',
#  1296605806: 'iBreathe',
#  1323264990: 'InnerHour: Self-Care Therapy',
#  337472899: 'Insight Timer',
#  1439590239: 'Jour: Daily Self-Care Journal',
#  909556526: 'Lyf',
#  1190294015: 'Meditopia: Meditation Coach',
#  1052216403: 'MindDoc',
#  634684825: 'MindShift CBT',
#  1054458809: 'Moodfit',
#  427064987: 'MoodKit',
#  1140332763: 'MoodMission',
#  778848692: 'MyLife Meditation',
#  1063365447: 'NOCD',
#  430646302: 'PTSD Coach',
#  1241229134: 'Reflectly',
#  961633456: 'Remente',
#  509287014: 'Rise Up + Recover',
#  1289018369: 'Rootd',
#  457360959: 'RR Eating Disorder Management',
#  922968861: 'Sanvello',
#  1444244578: 'Sayana',
#  1293721589: 'Shine',
#  560442518: 'Smiling Mind',
#  1158895079: 'Sober Time',
#  1506576652: 'Sowlmate',
#  1312926037: 'Stoic',
#  536634968: 'SuperBetter',
#  449804588: 'Talk Life',
#  661829386: 'Talkspace',
#  992210239: 'Ten Percent Happier',
#  1432324582: 'The Mighty',
#  825099621: 'Virtual Hope Box',
#  1307736395: 'Waking Up: Guided Meditation',
#  968251160: "What's Up?",
#  1273601356: 'Wisdo',
#  1305375832: 'Woebot',
#  693833917: 'Worry Watch',
#  1166585565: 'Wysa',
#  1060691513: 'Youper'}

# %%
as_rvws_slice.insert(0, 'app_name', as_rvws_slice['app_id'].map(as_name_map))

# %%
as_rvws_slice['as_rvw'] = 1
as_rvws_slice.drop(columns=['app_id'], inplace=True)
as_rvws_slice
# Out:
#        app_name                                             review  rating  \
# 0      Aloe Bud  I really am enjoying this app and once I start...       5
# 1      Aloe Bud  I have tried a lot of apps that said they woul...       5
# 2      Aloe Bud  IT JUST CAN'T GET MUCH BETTER! it really helps...       5
# 3      Aloe Bud  I don’t usually write reviews for apps, but I ...       5
# 4      Aloe Bud  Where to begin before I started using aloe bud...       5
# ...         ...                                                ...     ...
# 47316    Youper  I’m typically loaded with piss and vinegar but...       5
# 47317    Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 47318    Youper  I would love to get premium so I can utilize t...       2
# 47319    Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 47320    Youper  this app would be good to help me with my prob...       1
#
#                       date  as_rvw
# 0      2020-10-09 12:19:21       1
# 1      2021-03-01 03:51:42       1
# 2      2021-03-13 01:16:42       1
# 3      2020-06-29 12:20:49       1
# 4      2020-06-26 21:38:49       1
# ...                    ...     ...
# 47316  2020-03-14 01:16:42       1
# 47317  2020-03-07 00:50:10       1
# 47318  2020-03-13 02:47:24       1
# 47319  2021-03-24 18:32:13       1
# 47320  2021-03-24 13:49:56       1
#
# [47319 rows x 5 columns]

# %% [markdown]
# ### Concatenate All Reviews into Single DataFrame

# %%
all_rvws = pd.concat([gp_rvws_slice, as_rvws_slice])
all_rvws.head()
# Out:
#   app_name                                             review  rating  \
# 0     Aura                                            Awesome       5
# 1     Aura                              Great to help u sleep       5
# 2     Aura                             Very calming, love it!       5
# 3     Aura  I was able to sleep like a baby on the first u...       5
# 4     Aura        Improvement in thoughts, feelings and life!       5
#
#                   date  gp_rvw  as_rvw
# 0  2021-03-22 05:59:22     1.0     NaN
# 1  2021-03-21 20:29:44     1.0     NaN
# 2  2021-03-21 09:17:13     1.0     NaN
# 3  2021-03-21 09:09:57     1.0     NaN
# 4  2021-03-20 16:28:42     1.0     NaN

# %%
gp_id_map = {}
for app_name in app_df['app_name'].unique():
    value = app_df.loc[app_df['app_name']==app_name]['gp_id'].to_list()[0]
    gp_id_map[app_name] = value
gp_id_map
# Out:
# {'Aloe Bud': nan,
#  'Aura': 'com.aurahealth',
#  'BetterHelp': 'com.betterhelp',
#  'Breathe2Relax': 'org.t2health.breathe2relax',
#  'Breathwrk: Breathing Exercises': nan,
#  'Breethe: Meditation & Sleep': 'com.Meditation.app',
#  'Breeze: mood tracker, diary': nan,
#  'Calm': 'com.calm.android',
#  'CBT Thought Diary': 'com.moodtools.cbtassistant.app',
#  'Daylio': 'net.daylio',
#  'DBT Coach': 'co.swasth.dbtcoach',
#  'eMoods': 'my.tracker',
#  'eQuoo: Emotional Fitness Game': 'com.bitbox.equoo',
#  'Fabulous': 'co.thefabulous.app',
#  'GG OCD': 'air.com.samuramu.gg.oc',
#  'GG Self Care': 'com.ggtude.life',
#  'GG Self Esteem': 'air.com.samuramu.gg.se',
#  'Ginger': 'com.ginger',
#  'Habitica': 'com.habitrpg.android.habitica',
#  'Happify': 'com.happify.happifyinc',
#  'Happyfeed': 'com.happyfeed',
#  'Headspace': 'com.getsomeheadspace.android',
#  'Healthy Minds Program': 'com.healthyminds',
#  'HearMe': 'com.hearme',
#  'I Am Sober': 'com.thehungrywasp.iamsober',
#  'iBreathe': nan,
#  'InnerHour: Self-Care Therapy': 'com.theinnerhour.b2b',
#  'Insight Timer': 'com.spotlightsix.zentimerlite2',
#  'Jour: Daily Self-Care Journal': nan,
#  'Lyf': 'com.incogo.android',
#  'Meditopia: Meditation Coach': 'app.meditasyon',
#  'MindDoc': 'de.moodpath.android',
#  'MindShift CBT': 'com.bstro.MindShift',
#  'Moodfit': 'com.robleridge.Moodfit',
#  'MoodKit': nan,
#  'MoodMission': 'com.moodmission.moodmissionapp',
#  'MyLife Meditation': 'org.stopbreathethink.app',
#  'NOCD': 'com.treatmyocd.nocd',
#  'PTSD Coach': 'is.vertical.ptsdcoach',
#  'Reflectly': 'com.reflectlyApp',
#  'Remente': 'com.remente.app',
#  'Rise Up + Recover': 'com.rur',
#  'Rootd': 'com.rootd',
#  'RR Eating Disorder Management': 'com.recoveryrecord',
#  'Sanvello': 'com.pacificalabs.pacifica',
#  'Sayana': nan,
#  'Shine': 'com.shinetext.shine',
#  'Smiling Mind': 'com.smilingmind.app',
#  'Sober Time': 'com.sociosoft.sobertime',
#  'Sowlmate': nan,
#  'Stoic': nan,
#  'SuperBetter': 'com.superbetter.paid',
#  'Talk Life': 'com.bearpty.talklife',
#  'Talkspace': 'com.talkspace.talkspaceapp',
#  'Ten Percent Happier': 'com.changecollective.tenpercenthappier',
#  'The Mighty': 'com.themighty',
#  'Virtual Hope Box': 'com.t2.vhb',
#  'Waking Up: Guided Meditation': 'org.wakingup.android',
#  "What's Up?": 'com.jacksontempra.apps.whatsup',
#  'Wisdo': 'com.wisdo.android.wisdo',
#  'Woebot': 'com.woebot',
#  'Worry Watch': nan,
#  'Wysa': 'bot.touchkin',
#  'Youper': nan}

# %%
as_id_map = {}
for k,v in as_name_map.items():
    as_id_map[v] = k
as_id_map
# Out:
# {'Aloe Bud': 1318382054,
#  'Aura': 1114223104,
#  'BetterHelp': 995252384,
#  'Breathe2Relax': 425720246,
#  'Breathwrk: Breathing Exercises': 1481804500,
#  'Breethe: Meditation & Sleep': 920161006,
#  'Breeze: mood tracker, diary': 1450365119,
#  'Calm': 571800810,
#  'CBT Thought Diary': 1010391170,
#  'Daylio': 1194023242,
#  'DBT Coach': 1452264969,
#  'eMoods': 1184456130,
#  'eQuoo: Emotional Fitness Game': 1318726049,
#  'Fabulous': 1203637303,
#  'GG OCD': 1140486359,
#  'GG Self Care': 1489604281,
#  'GG Self Esteem': 1300107718,
#  'Ginger': 515118602,
#  'Habitica': 994882113,
#  'Happify': 730601963,
#  'Happyfeed': 707073943,
#  'Headspace': 493145008,
#  'Healthy Minds Program': 1326310617,
#  'HearMe': 1417672401,
#  'I Am Sober': 672904239,
#  'iBreathe': 1296605806,
#  'InnerHour: Self-Care Therapy': 1323264990,
#  'Insight Timer': 337472899,
#  'Jour: Daily Self-Care Journal': 1439590239,
#  'Lyf': 909556526,
#  'Meditopia: Meditation Coach': 1190294015,
#  'MindDoc': 1052216403,
#  'MindShift CBT': 634684825,
#  'Moodfit': 1054458809,
#  'MoodKit': 427064987,
#  'MoodMission': 1140332763,
#  'MyLife Meditation': 778848692,
#  'NOCD': 1063365447,
#  'PTSD Coach': 430646302,
#  'Reflectly': 1241229134,
#  'Remente': 961633456,
#  'Rise Up + Recover': 509287014,
#  'Rootd': 1289018369,
#  'RR Eating Disorder Management': 457360959,
#  'Sanvello': 922968861,
#  'Sayana': 1444244578,
#  'Shine': 1293721589,
#  'Smiling Mind': 560442518,
#  'Sober Time': 1158895079,
#  'Sowlmate': 1506576652,
#  'Stoic': 1312926037,
#  'SuperBetter': 536634968,
#  'Talk Life': 449804588,
#  'Talkspace': 661829386,
#  'Ten Percent Happier': 992210239,
#  'The Mighty': 1432324582,
#  'Virtual Hope Box': 825099621,
#  'Waking Up: Guided Meditation': 1307736395,
#  "What's Up?": 968251160,
#  'Wisdo': 1273601356,
#  'Woebot': 1305375832,
#  'Worry Watch': 693833917,
#  'Wysa': 1166585565,
#  'Youper': 1060691513}

# %%
all_rvws['as_id'] = all_rvws['app_name'].map(as_id_map)
all_rvws['gp_id'] = all_rvws['app_name'].map(gp_id_map)
all_rvws
# Out:
#       app_name                                             review  rating  \
# 0         Aura                                            Awesome       5
# 1         Aura                              Great to help u sleep       5
# 2         Aura                             Very calming, love it!       5
# 3         Aura  I was able to sleep like a baby on the first u...       5
# 4         Aura        Improvement in thoughts, feelings and life!       5
# ...        ...                                                ...     ...
# 47316   Youper  I’m typically loaded with piss and vinegar but...       5
# 47317   Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 47318   Youper  I would love to get premium so I can utilize t...       2
# 47319   Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 47320   Youper  this app would be good to help me with my prob...       1
#
#                       date  gp_rvw  as_rvw       as_id           gp_id
# 0      2021-03-22 05:59:22     1.0     NaN  1114223104  com.aurahealth
# 1      2021-03-21 20:29:44     1.0     NaN  1114223104  com.aurahealth
# 2      2021-03-21 09:17:13     1.0     NaN  1114223104  com.aurahealth
# 3      2021-03-21 09:09:57     1.0     NaN  1114223104  com.aurahealth
# 4      2021-03-20 16:28:42     1.0     NaN  1114223104  com.aurahealth
# ...                    ...     ...     ...         ...             ...
# 47316  2020-03-14 01:16:42     NaN     1.0  1060691513             NaN
# 47317  2020-03-07 00:50:10     NaN     1.0  1060691513             NaN
# 47318  2020-03-13 02:47:24     NaN     1.0  1060691513             NaN
# 47319  2021-03-24 18:32:13     NaN     1.0  1060691513             NaN
# 47320  2021-03-24 13:49:56     NaN     1.0  1060691513             NaN
#
# [468755 rows x 8 columns]

# %%
all_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 468755 entries, 0 to 47320
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   app_name  468755 non-null  object
#  1   review    468755 non-null  object
#  2   rating    468755 non-null  int64
#  3   date      468755 non-null  object
#  4   gp_rvw    421436 non-null  float64
#  5   as_rvw    47319 non-null   float64
#  6   as_id     468755 non-null  int64
#  7   gp_id     463014 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 32.2+ MB

# %%
all_rvws['gp_rvw'].fillna(0, inplace=True)
all_rvws['gp_rvw'] = all_rvws['gp_rvw'].astype('int64')
all_rvws['as_rvw'].fillna(0, inplace=True)
all_rvws['as_rvw'] = all_rvws['as_rvw'].astype('int64')
all_rvws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 468755 entries, 0 to 47320
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   app_name  468755 non-null  object
#  1   review    468755 non-null  object
#  2   rating    468755 non-null  int64
#  3   date      468755 non-null  object
#  4   gp_rvw    468755 non-null  int64
#  5   as_rvw    468755 non-null  int64
#  6   as_id     468755 non-null  int64
#  7   gp_id     463014 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 32.2+ MB

# %%
all_rvws
# Out:
#       app_name                                             review  rating  \
# 0         Aura                                            Awesome       5
# 1         Aura                              Great to help u sleep       5
# 2         Aura                             Very calming, love it!       5
# 3         Aura  I was able to sleep like a baby on the first u...       5
# 4         Aura        Improvement in thoughts, feelings and life!       5
# ...        ...                                                ...     ...
# 47316   Youper  I’m typically loaded with piss and vinegar but...       5
# 47317   Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 47318   Youper  I would love to get premium so I can utilize t...       2
# 47319   Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 47320   Youper  this app would be good to help me with my prob...       1
#
#                       date  gp_rvw  as_rvw       as_id           gp_id
# 0      2021-03-22 05:59:22       1       0  1114223104  com.aurahealth
# 1      2021-03-21 20:29:44       1       0  1114223104  com.aurahealth
# 2      2021-03-21 09:17:13       1       0  1114223104  com.aurahealth
# 3      2021-03-21 09:09:57       1       0  1114223104  com.aurahealth
# 4      2021-03-20 16:28:42       1       0  1114223104  com.aurahealth
# ...                    ...     ...     ...         ...             ...
# 47316  2020-03-14 01:16:42       0       1  1060691513             NaN
# 47317  2020-03-07 00:50:10       0       1  1060691513             NaN
# 47318  2020-03-13 02:47:24       0       1  1060691513             NaN
# 47319  2021-03-24 18:32:13       0       1  1060691513             NaN
# 47320  2021-03-24 13:49:56       0       1  1060691513             NaN
#
# [468755 rows x 8 columns]

# %%
# Import spaCy and load the language library
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Import from sklearn to build class to fit_transform review text
import sklearn
from sklearn.base import TransformerMixin, BaseEstimator

# %%
class TextPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self,
                 user_abbrevs={},
                 n_jobs=1):

# %%
all_rvws_slice = all_rvws[-10:].copy()
all_rvws_slice.reset_indexdex(inplace=True)
all_rvws_slice
# Out:
#    index app_name                                             review  rating  \
# 0  47311   Youper  Since the “bug fix” i haven’t even been able t...       1
# 1  47312   Youper  I’ve only had this for a few days now and it’s...       5
# 2  47313   Youper  I like it I just wish it wasn’t 60.00 for the ...       5
# 3  47314   Youper                                            1000/10       5
# 4  47315   Youper  You can tell what kind of a day you are having...       5
# 5  47316   Youper  I’m typically loaded with piss and vinegar but...       5
# 6  47317   Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 7  47318   Youper  I would love to get premium so I can utilize t...       2
# 8  47319   Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 9  47320   Youper  this app would be good to help me with my prob...       1
#
#                   date  gp_rvw  as_rvw       as_id gp_id
# 0  2020-04-15 17:09:55       0       1  1060691513   NaN
# 1  2020-04-13 07:48:27       0       1  1060691513   NaN
# 2  2020-04-02 04:04:37       0       1  1060691513   NaN
# 3  2020-03-30 21:18:16       0       1  1060691513   NaN
# 4  2020-03-24 02:03:46       0       1  1060691513   NaN
# 5  2020-03-14 01:16:42       0       1  1060691513   NaN
# 6  2020-03-07 00:50:10       0       1  1060691513   NaN
# 7  2020-03-13 02:47:24       0       1  1060691513   NaN
# 8  2021-03-24 18:32:13       0       1  1060691513   NaN
# 9  2021-03-24 13:49:56       0       1  1060691513   NaN

# %%
all_rvws_slice['raw_rvw_doc'] = all_rvws_slice['review'].apply(nlp)
all_rvws_slice
# Out:
#    index app_name                                             review  rating  \
# 0  47311   Youper  Since the “bug fix” i haven’t even been able t...       1
# 1  47312   Youper  I’ve only had this for a few days now and it’s...       5
# 2  47313   Youper  I like it I just wish it wasn’t 60.00 for the ...       5
# 3  47314   Youper                                            1000/10       5
# 4  47315   Youper  You can tell what kind of a day you are having...       5
# 5  47316   Youper  I’m typically loaded with piss and vinegar but...       5
# 6  47317   Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 7  47318   Youper  I would love to get premium so I can utilize t...       2
# 8  47319   Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 9  47320   Youper  this app would be good to help me with my prob...       1
#
#                   date  gp_rvw  as_rvw       as_id gp_id  \
# 0  2020-04-15 17:09:55       0       1  1060691513   NaN
# 1  2020-04-13 07:48:27       0       1  1060691513   NaN
# 2  2020-04-02 04:04:37       0       1  1060691513   NaN
# 3  2020-03-30 21:18:16       0       1  1060691513   NaN
# 4  2020-03-24 02:03:46       0       1  1060691513   NaN
# 5  2020-03-14 01:16:42       0       1  1060691513   NaN
# 6  2020-03-07 00:50:10       0       1  1060691513   NaN
# 7  2020-03-13 02:47:24       0       1  1060691513   NaN
# 8  2021-03-24 18:32:13       0       1  1060691513   NaN
# 9  2021-03-24 13:49:56       0       1  1060691513   NaN
#
#                                          raw_rvw_doc
# 0  (Since, the, “, bug, fix, ”, i, have, n’t, eve...
# 1  (I, ’ve, only, had, this, for, a, few, days, n...
# 2  (I, like, it, I, just, wish, it, was, n’t, 60....
# 3                                          (1000/10)
# 4  (You, can, tell, what, kind, of, a, day, you, ...
# 5  (I, ’m, typically, loaded, with, piss, and, vi...
# 6  (Hi, ,, I, ’ve, been, struggling, with, my, BP...
# 7  (I, would, love, to, get, premium, so, I, can,...
# 8  (It, does, n’t, load, ., \n, It, costs, WAY, t...
# 9  (this, app, would, be, good, to, help, me, wit...

# %%
all_rvws_slice['raw_rvw_doc'][2]
# Out:
# I like it I just wish it wasn’t 60.00 for the premium. It’s nice to keep track of how I feel

# %%
type(all_rvws_slice['raw_rvw_doc'][2])
# Out:
# spacy.tokens.doc.Doc

# %%
for sent in all_rvws_slice['raw_rvw_doc'][2].sents:
    print(sent, '\n')
# Out:
# I like it
#
# I just wish it wasn’t 60.00 for the premium.
#
# It’s nice to keep track of how I feel

# %%
for token in all_rvws_slice['raw_rvw_doc'][2]:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.dep_:{10}} {token.lemma_:{12}}')
# Out:
# I            PRON   nsubj      I
# like         VERB   ROOT       like
# it           PRON   dobj       it
# I            PRON   nsubj      I
# just         ADV    advmod     just
# wish         VERB   ROOT       wish
# it           PRON   nsubj      it
# was          AUX    ccomp      be
# n’t          PART   neg        n’t
# 60.00        NUM    attr       60.00
# for          ADP    prep       for
# the          DET    det        the
# premium      NOUN   pobj       premium
# .            PUNCT  punct      .
# It           PRON   nsubj      it
# ’s           VERB   ROOT       ’
# nice         ADJ    acomp      nice
# to           PART   aux        to
# keep         VERB   xcomp      keep
# track        NOUN   dobj       track
# of           ADP    prep       of
# how          ADV    advmod     how
# I            PRON   nsubj      I
# feel         VERB   pcomp      feel

# %%
all_rvws_slice['num_sents'] = all_rvws_slice['raw_rvw_doc'].apply(lambda x: len([sent for sent in x.sents]))
all_rvws_slice
# Out:
#    index app_name                                             review  rating  \
# 0  47311   Youper  Since the “bug fix” i haven’t even been able t...       1
# 1  47312   Youper  I’ve only had this for a few days now and it’s...       5
# 2  47313   Youper  I like it I just wish it wasn’t 60.00 for the ...       5
# 3  47314   Youper                                            1000/10       5
# 4  47315   Youper  You can tell what kind of a day you are having...       5
# 5  47316   Youper  I’m typically loaded with piss and vinegar but...       5
# 6  47317   Youper  Hi, I’ve been struggling with my BPD, depressi...       5
# 7  47318   Youper  I would love to get premium so I can utilize t...       2
# 8  47319   Youper  It doesn’t load.\nIt costs WAY too much.\nIt’s...       1
# 9  47320   Youper  this app would be good to help me with my prob...       1
#
#                   date  gp_rvw  as_rvw       as_id gp_id  \
# 0  2020-04-15 17:09:55       0       1  1060691513   NaN
# 1  2020-04-13 07:48:27       0       1  1060691513   NaN
# 2  2020-04-02 04:04:37       0       1  1060691513   NaN
# 3  2020-03-30 21:18:16       0       1  1060691513   NaN
# 4  2020-03-24 02:03:46       0       1  1060691513   NaN
# 5  2020-03-14 01:16:42       0       1  1060691513   NaN
# 6  2020-03-07 00:50:10       0       1  1060691513   NaN
# 7  2020-03-13 02:47:24       0       1  1060691513   NaN
# 8  2021-03-24 18:32:13       0       1  1060691513   NaN
# 9  2021-03-24 13:49:56       0       1  1060691513   NaN
#
#                                          raw_rvw_doc  num_sents
# 0  (Since, the, “, bug, fix, ”, i, have, n’t, eve...          3
# 1  (I, ’ve, only, had, this, for, a, few, days, n...          4
# 2  (I, like, it, I, just, wish, it, was, n’t, 60....          3
# 3                                          (1000/10)          1
# 4  (You, can, tell, what, kind, of, a, day, you, ...          2
# 5  (I, ’m, typically, loaded, with, piss, and, vi...          2
# 6  (Hi, ,, I, ’ve, been, struggling, with, my, BP...          9
# 7  (I, would, love, to, get, premium, so, I, can,...          2
# 8  (It, does, n’t, load, ., \n, It, costs, WAY, t...          7
# 9  (this, app, would, be, good, to, help, me, wit...          2

# %%
all_rvws_slice['raw_rvw_doc'][9]
# Out:
# this app would be good to help me with my problems and make me feel bette did i didn’t have to pay to use literally everything it says i need to get better, i don’t have a credit card or very much money in general and i’m also very depressed, i would like to be helped and feel better but i cannot pay to use everything on here

# %%
all_rvws_slice['raw_rvw_doc'][6]
# Out:
# Hi, I’ve been struggling with my BPD, depression, anxiety (social, and generalized). I had a hard time sticking to the plans my therapist and I would make together, and would often get really lost in my old habits and thinking patterns, making progress difficult. Having this assistant to create reminders and “rewire” to help between therapy sessions is already helping me so much. Being able to keep track of my symptoms is so helpful.
# Thank you for making this app! I’ve been sharing it with all of my friends. 🖤

# %%
all_rvws_slice['raw_rvw_doc'][8]
# Out:
# It doesn’t load.
# It costs WAY too much.
# It’s too crazy and changes too much.
#
# Go to Sanvello, everyone! It’s what Youper used to be before they changed everything!!

# %%
for token in all_rvws_slice['raw_rvw_doc'][8]:
    print(f'{token.text:{12}} {token.pos_:{6}} {token.dep_:{10}} {token.lemma_:{12}}')
# Out:
# It           PRON   nsubj      it
# does         AUX    aux        do
# n’t          PART   neg        n’t
# load         VERB   ROOT       load
# .            PUNCT  punct      .
#
#             SPACE  ROOT
#
# It           PRON   nsubj      it
# costs        VERB   ROOT       cost
# WAY          NOUN   dobj       way
# too          ADV    advmod     too
# much         ADV    advmod     much
# .            PUNCT  punct      .
#
#             SPACE  ROOT
#
# It           PRON   nsubj      it
# ’s           VERB   ROOT       ’
# too          ADV    advmod     too
# crazy        ADJ    acomp      crazy
# and          CCONJ  cc         and
# changes      VERB   conj       change
# too          ADV    advmod     too
# much         ADV    advmod     much
# .            PUNCT  punct      .
#
#
#            SPACE  ROOT
#
#
# Go           VERB   xcomp      go
# to           ADP    prep       to
# Sanvello     PROPN  pobj       Sanvello
# ,            PUNCT  punct      ,
# everyone     PRON   npadvmod   everyone
# !            PUNCT  punct      !
# It           PRON   nsubj      it
# ’s           VERB   ROOT       ’
# what         PRON   dobj       what
# Youper       PROPN  nsubj      Youper
# used         VERB   ccomp      use
# to           PART   aux        to
# be           VERB   xcomp      be
# before       ADP    mark       before
# they         PRON   nsubj      they
# changed      VERB   advcl      change
# everything   PRON   dobj       everything
# !            PUNCT  punct      !
# !            PUNCT  punct      !
